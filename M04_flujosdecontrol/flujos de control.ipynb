# %%
num1=55
num2=6

# %%
if num1>num2:
    print(num1, " Es mayor 1")
elif num2+num1:
    print(num2, " Es mayor 2")
# Out:
# 55  Es mayor 1

# %%
#ciclos for
for i in range(1,6): #rando de de 1a6
    suma=i+1
    print("Variable de iteracion: ",i, "resultado suma: ",suma)
# Out:
# Variable de iteracion:  1 resultado suma:  2
# Variable de iteracion:  2 resultado suma:  3
# Variable de iteracion:  3 resultado suma:  4
# Variable de iteracion:  4 resultado suma:  5
# Variable de iteracion:  5 resultado suma:  6

# %%
numeros = [1,2,3,4,5]
for num in numeros:
    suma= num+1
    print(suma)
# Out:
# 2
# 3
# 4
# 5
# 6
